# %% [raw]
# import datalook

# %%
help(datalook.analyse)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-0b6359055620> in <module>()
# ----> 1 help(datalook.analyse)
#
# NameError: name 'datalook' is not defined

# %%
import datalook

# %%
datalook.analyse('data/data/weather-02.csv')
